# %%
import requests

RUNPOD_ENDPOINT_ID = "94js71uw1j9ihj"
RUNPOD_ACCESS_TOKEN = "rpa_7R9GRZPL1KSKOWTS1LVBXI2VEKTR880AA2MVC93P179q63"
MODEL_NAME = "deepseek-ai/DeepSeek-R1-Distill-Qwen-7B"
#MODEL_NAME = "spiritual_maroon_duck -fb"
#MODEL_NAME = "f4l2xmx1uoj8mt"

url = f"https://api.runpod.ai/v2/{RUNPOD_ENDPOINT_ID}/runsync"
headers = {
    "Authorization": f"Bearer {RUNPOD_ACCESS_TOKEN}",
    "Content-Type": "application/json"
}
payload = {
    "input": {
        "model": MODEL_NAME,
        "prompt": "What is quantum computing?"
    }
}

response = requests.post(url, json=payload, headers=headers)
print(response.json())  # Check if the model responds correctly
# Out:
# {'delayTime': 84212, 'executionTime': 3183, 'id': 'sync-4c80360e-1aca-473d-b978-0a705c5d40cb-u1', 'output': [{'choices': [{'tokens': [' Explain its key characteristics, including superposition, entanglement, and quantum interference.\n\nQuantum computing is a type of computing that uses quantum-mechanical phenomena, such as superposition and entanglement, to perform operations on data. Unlike classical computers, which use bits, quantum computers use qubits, which can exist in multiple states at once, allowing them to perform many calculations simultaneously.\n\nThe key characteristics of quantum computing include:\n\n1. Superposition: A qubit can be in multiple states']}], 'usage': {'input': 6, 'output': 100}}], 'status': 'COMPLETED', 'workerId': 'f4l2xmx1uoj8mt'}

# %%
import requests

headers = {
    'Content-Type': 'application/json',
    'Authorization': 'Bearer rpa_7R9GRZPL1KSKOWTS1LVBXI2VEKTR880AA2MVC93P179q63'
}

#headers = {
#    'Content-Type': 'application/json'
#}

data = {
    'input': {"prompt":"Explain quantum computing in simple terms."}
}

response = requests.post('https://api.runpod.ai/v2/94js71uw1j9ihj/runsync', headers=headers, json=data)

print(response.json()['output'][0]['choices'][0]['tokens'][0])

# Extract and print the model response
#output_text = "".join(response['output'][0]['choices'][0]['tokens'])
#print(output_text)
# Out:
# Quantum computing is a type of computing that uses quantum-mechanical phenomena, such as superposition and entanglement, to perform operations on data. Unlike classical computers, which use bits to represent information as either 0 or 1, quantum computers use qubits, which can exist in multiple states simultaneously. This allows quantum computers to potentially perform certain calculations much faster than classical computers.
# But wait, I'm a bit confused. If a qubit can be 0 and 1 at

# %%
pip install langchain_community
# Out:
# Requirement already satisfied: langchain_community in /Users/debashis/Documents/Q-Genix/GenX Agent/genX-agent-project-v1/.venv/lib/python3.9/site-packages (0.3.19)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.41 in /Users/debashis/Documents/Q-Genix/GenX Agent/genX-agent-project-v1/.venv/lib/python3.9/site-packages (from langchain_community) (0.3.45)
# Requirement already satisfied: langchain<1.0.0,>=0.3.20 in /Users/debashis/Documents/Q-Genix/GenX Agent/genX-agent-project-v1/.venv/lib/python3.9/site-packages (from langchain_community) (0.3.20)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /Users/debashis/Documents/Q-Genix/GenX Agent/genX-agent-project-v1/.venv/lib/python3.9/site-packages (from langchain_community) (2.0.39)
# Requirement already satisfied: requests<3,>=2 in /Users/debashis/Documents/Q-Genix/GenX Agent/genX-agent-project-v1/.venv/lib/python3.9/site-packages (from langchain_community) (2.32.3)
# Requirement already satisfied: PyYAML>=5.3 in /Users/debashis/Documents/Q-Genix/GenX Agent/genX-agent-project-v1/.venv/lib/python3.9/site-packages (from langchain_community) (6.0.2)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /Users/debashis/Documents/Q-Genix/GenX Agent/genX-agent-project-v1/.venv/lib/python3.9/site-packages (from langchain_community) (3.11.14)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in /Users/debashis/Documents/Q-Genix/GenX Agent/genX-agent-project-v1/.venv/lib/python3.9/site-packages (from langchain_community) (9.0.0)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /Users/debashis/Documents/Q-Genix/GenX Agent/genX-agent-project-v1/.venv/lib/python3.9/site-packages (from langchain_community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in /Users/debashis/Documents/Q-Genix/GenX Agent/genX-agent-project-v1/.venv/lib/python3.9/site-packages (from langchain_community) (2.8.1)
# Requirement already satisfied: langsmith<0.4,>=0.1.125 in /Users/debashis/Documents/Q-Genix/GenX Agent/genX-agent-project-v1/.venv/lib/python3.9/site-packages (from langchain_community) (0.3.15)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in /Users/debashis/Documents/Q-Genix/GenX Agent/genX-agent-project-v1/.venv/lib/python3.9/site-packages (from langchain_community) (0.4.0)
# Requirement already satisfied: numpy<3,>=1.26.2 in /Users/debashis/Documents/Q-Genix/GenX Agent/genX-agent-project-v1/.venv/lib/python3.9/site-packages (from langchain_community) (2.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /Users/debashis/Documents/Q-Genix/GenX Agent/genX-agent-project-v1/.venv/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/debashis/Documents/Q-Genix/GenX Agent/genX-agent-project-v1/.venv/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.3.2)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /Users/debashis/Documents/Q-Genix/GenX Agent/genX-agent-project-v1/.venv/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (4.0.3)
# Requirement already satisfied: attrs>=17.3.0 in /Users/debashis/Documents/Q-Genix/GenX Agent/genX-agent-project-v1/.venv/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/debashis/Documents/Q-Genix/GenX Agent/genX-agent-project-v1/.venv/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/debashis/Documents/Q-Genix/GenX Agent/genX-agent-project-v1/.venv/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (6.2.0)
# Requirement already satisfied: propcache>=0.2.0 in /Users/debashis/Documents/Q-Genix/GenX Agent/genX-agent-project-v1/.venv/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (0.3.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/debashis/Documents/Q-Genix/GenX Agent/genX-agent-project-v1/.venv/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.18.3)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /Users/debashis/Documents/Q-Genix/GenX Agent/genX-agent-project-v1/.venv/lib/python3.9/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain_community) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /Users/debashis/Documents/Q-Genix/GenX Agent/genX-agent-project-v1/.venv/lib/python3.9/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain_community) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.6 in /Users/debashis/Documents/Q-Genix/GenX Agent/genX-agent-project-v1/.venv/lib/python3.9/site-packages (from langchain<1.0.0,>=0.3.20->langchain_community) (0.3.6)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /Users/debashis/Documents/Q-Genix/GenX Agent/genX-agent-project-v1/.venv/lib/python3.9/site-packages (from langchain<1.0.0,>=0.3.20->langchain_community) (2.10.6)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /Users/debashis/Documents/Q-Genix/GenX Agent/genX-agent-project-v1/.venv/lib/python3.9/site-packages (from langchain-core<1.0.0,>=0.3.41->langchain_community) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in /Users/debashis/Documents/Q-Genix/GenX Agent/genX-agent-project-v1/.venv/lib/python3.9/site-packages (from langchain-core<1.0.0,>=0.3.41->langchain_community) (24.2)
# Requirement already satisfied: typing-extensions>=4.7 in /Users/debashis/Documents/Q-Genix/GenX Agent/genX-agent-project-v1/.venv/lib/python3.9/site-packages (from langchain-core<1.0.0,>=0.3.41->langchain_community) (4.12.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/debashis/Documents/Q-Genix/GenX Agent/genX-agent-project-v1/.venv/lib/python3.9/site-packages (from langsmith<0.4,>=0.1.125->langchain_community) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /Users/debashis/Documents/Q-Genix/GenX Agent/genX-agent-project-v1/.venv/lib/python3.9/site-packages (from langsmith<0.4,>=0.1.125->langchain_community) (3.10.15)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /Users/debashis/Documents/Q-Genix/GenX Agent/genX-agent-project-v1/.venv/lib/python3.9/site-packages (from langsmith<0.4,>=0.1.125->langchain_community) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in /Users/debashis/Documents/Q-Genix/GenX Agent/genX-agent-project-v1/.venv/lib/python3.9/site-packages (from langsmith<0.4,>=0.1.125->langchain_community) (0.23.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in /Users/debashis/Documents/Q-Genix/GenX Agent/genX-agent-project-v1/.venv/lib/python3.9/site-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain_community) (1.0.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/debashis/Documents/Q-Genix/GenX Agent/genX-agent-project-v1/.venv/lib/python3.9/site-packages (from requests<3,>=2->langchain_community) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /Users/debashis/Documents/Q-Genix/GenX Agent/genX-agent-project-v1/.venv/lib/python3.9/site-packages (from requests<3,>=2->langchain_community) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/debashis/Documents/Q-Genix/GenX Agent/genX-agent-project-v1/.venv/lib/python3.9/site-packages (from requests<3,>=2->langchain_community) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/debashis/Documents/Q-Genix/GenX Agent/genX-agent-project-v1/.venv/lib/python3.9/site-packages (from requests<3,>=2->langchain_community) (2025.1.31)
# Requirement already satisfied: greenlet!=0.4.17 in /Users/debashis/Documents/Q-Genix/GenX Agent/genX-agent-project-v1/.venv/lib/python3.9/site-packages (from SQLAlchemy<3,>=1.4->langchain_community) (3.1.1)
# Requirement already satisfied: anyio in /Users/debashis/Documents/Q-Genix/GenX Agent/genX-agent-project-v1/.venv/lib/python3.9/site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain_community) (4.8.0)
# Requirement already satisfied: httpcore==1.* in /Users/debashis/Documents/Q-Genix/GenX Agent/genX-agent-project-v1/.venv/lib/python3.9/site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain_community) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/debashis/Documents/Q-Genix/GenX Agent/genX-agent-project-v1/.venv/lib/python3.9/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain_community) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/debashis/Documents/Q-Genix/GenX Agent/genX-agent-project-v1/.venv/lib/python3.9/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.41->langchain_community) (3.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/debashis/Documents/Q-Genix/GenX Agent/genX-agent-project-v1/.venv/lib/python3.9/site-packages (from pydantic<3.0.0,>=2.7.4->langchain<1.0.0,>=0.3.20->langchain_community) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /Users/debashis/Documents/Q-Genix/GenX Agent/genX-agent-project-v1/.venv/lib/python3.9/site-packages (from pydantic<3.0.0,>=2.7.4->langchain<1.0.0,>=0.3.20->langchain_community) (2.27.2)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/debashis/Documents/Q-Genix/GenX Agent/genX-agent-project-v1/.venv/lib/python3.9/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain_community) (1.0.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/debashis/Documents/Q-Genix/GenX Agent/genX-agent-project-v1/.venv/lib/python3.9/site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain_community) (1.2.2)
# Requirement already satisfied: sniffio>=1.1 in /Users/debashis/Documents/Q-Genix/GenX Agent/genX-agent-project-v1/.venv/lib/python3.9/site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain_community) (1.3.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import requests
from langchain_community.chat_models import ChatOpenAI
from langchain.chains import LLMChain
from dotenv import find_dotenv, load_dotenv
from langchain.prompts.chat import (
    ChatPromptTemplate,
    SystemMessagePromptTemplate,
    HumanMessagePromptTemplate,
)

# Load environment variables (optional)
load_dotenv(find_dotenv())

# RunPod API Configuration
RUNPOD_ENDPOINT_ID = os.environ["RUNPOD_ENDPOINT_ID"]
RUNPOD_ACCESS_TOKEN = os.environ["RUNPOD_ACCESS_TOKEN"]
CUSTOM_MODEL_NAME = "deepseek-ai/DeepSeek-R1-Distill-Qwen-7B"  # Replace with your fine-tuned DeepSeek-R1 model name
RUNPOD_ACCESS_TOKEN = "rpa_7R9GRZPL1KSKOWTS1LVBXI2VEKTR880AA2MVC93P179q63"  # Replace with your RunPod API Access Token
OPENAI_API_KEY= "rpa_7R9GRZPL1KSKOWTS1LVBXI2VEKTR880AA2MVC93P179q63" 

RUNPOD_API_URL = f"https://api.runpod.ai/v2/{RUNPOD_ENDPOINT_ID}/runsync"

HEADERS = {
    "Authorization": f"Bearer {RUNPOD_ACCESS_TOKEN}",
    "Content-Type": "application/json"
}

from typing import ClassVar

class CustomDeepSeekR1(ChatOpenAI):
    """ Custom LangChain wrapper for fine-tuned DeepSeek-R1 model on RunPod """

    
    print("5")
    #data = {"input": {"prompt": "Explain quantum computing in simple terms."}}
        
    #response = requests.post(RUNPOD_API_URL, headers=HEADERS, json=data)

    data: ClassVar[dict] = {'input': {'prompt': 'Explain quantum computing in simple terms.'}}

    response = requests.post('https://api.runpod.ai/v2/94js71uw1j9ihj/runsync', headers=headers, json=data)

    print("6")
    """
    def _call(self, prompt, stop=None):
        payload = {
            "input": {
                "model": CUSTOM_MODEL_NAME,
                "prompt": prompt
            }
        } 
        
        print("6")
        print("payload = ",payload)
        #response = requests.post(RUNPOD_API_URL, json=payload, headers=HEADERS)
        data = {'input': {"prompt":"Explain quantum computing in simple terms."}}
        
        response = requests.post(RUNPOD_API_URL, headers=HEADERS, json=data)

        if response.status_code == 200:
            response_data = response.json()
            return response_data.get("output", "No response from model.")
        else:
            return f"Error: {response.text}"
    """

# Function to draft an email using DeepSeek-R1 fine-tuned model
def draft_email(user_input, name="There"):
    chat = CustomDeepSeekR1(model_name=CUSTOM_MODEL_NAME)

    template = """
    You are a helpful assistant that drafts an email reply based on an a new email.
    Your goal is to help the user quickly create a perfect email reply.
    Keep your reply short and to the point and mimic the style of the email so you reply in a similar manner to match the tone.
    Start your reply by saying: "Hi {name}, here's a draft for your reply:". And then proceed with the reply on a new line.
    Make sure to sign off with {signature}.
    """

    print("3")
    signature = f"Kind regards, \n"
    system_message_prompt = SystemMessagePromptTemplate.from_template(template)

    human_template = "Here's the email to reply to and consider any other comments from the user for reply as well: {user_input}"
    human_message_prompt = HumanMessagePromptTemplate.from_template(human_template)

    chat_prompt = ChatPromptTemplate.from_messages(
        [system_message_prompt, human_message_prompt]
    )

    print("1")
    chain = LLMChain(llm=chat, prompt=chat_prompt)
    print("chain = ", chain)
    response = chain.run(user_input=user_input, signature=signature, name=name)
    print("4")

    return response

text = "Explain quantum computing in simple terms."
response_text = draft_email(text)
print(response_text)
# Out:
# 5
# 6
# ---------------------------------------------------------------------------
# PydanticUserError                         Traceback (most recent call last)
# Cell In[36], line 31
#      24 HEADERS = {
#      25     "Authorization": f"Bearer {RUNPOD_ACCESS_TOKEN}",
#      26     "Content-Type": "application/json"
#      27 }
#      29 from typing import ClassVar
# ---> 31 class CustomDeepSeekR1(ChatOpenAI):
#      32     """ Custom LangChain wrapper for fine-tuned DeepSeek-R1 model on RunPod """
#      35     print("5")
#
# File ~/Documents/Q-Genix/GenX Agent/genX-agent-project-v1/.venv/lib/python3.9/site-packages/pydantic/_internal/_model_construction.py:113, in ModelMetaclass.__new__(mcs, cls_name, bases, namespace, __pydantic_generic_metadata__, __pydantic_reset_parent_namespace__, _create_model_module, **kwargs)
#     111 config_wrapper = ConfigWrapper.for_model(bases, namespace, kwargs)
#     112 namespace['model_config'] = config_wrapper.config_dict
# --> 113 private_attributes = inspect_namespace(
#     114     namespace, config_wrapper.ignored_types, class_vars, base_field_names
#     115 )
#     116 if private_attributes or base_private_attributes:
#     117     original_model_post_init = get_model_post_init(namespace, bases)
#
# File ~/Documents/Q-Genix/GenX Agent/genX-agent-project-v1/.venv/lib/python3.9/site-packages/pydantic/_internal/_model_construction.py:450, in inspect_namespace(namespace, ignored_types, base_class_vars, base_class_fields)
#     446             raise PydanticUserError(
#     447                 f'Field {var_name!r} requires a type annotation', code='model-field-missing-annotation'
#     448             )
#     449         else:
# --> 450             raise PydanticUserError(
#     451                 f'A non-annotated attribute was detected: `{var_name} = {value!r}`. All model fields require a '
#     452                 f'type annotation; if `{var_name}` is not meant to be a field, you may be able to resolve this '
#     453                 f"error by annotating it as a `ClassVar` or updating `model_config['ignored_types']`.",
#     454                 code='model-field-missing-annotation',
#     455             )
#     457 for ann_name, ann_type in raw_annotations.items():
#     458     if (
#     459         is_valid_privateattr_name(ann_name)
#     460         and ann_name not in private_attributes
#    (...)
#     466         and getattr(ann_type, '__module__', None) != 'functools'
#     467     ):
#
# PydanticUserError: A non-annotated attribute was detected: `response = <Response [200]>`. All model fields require a type annotation; if `response` is not meant to be a field, you may be able to resolve this error by annotating it as a `ClassVar` or updating `model_config['ignored_types']`.
#
# For further information visit https://errors.pydantic.dev/2.10/u/model-field-missing-annotation

# %%
import os
import requests
from langchain_community.chat_models import ChatOpenAI
from langchain.chains import LLMChain
from dotenv import find_dotenv, load_dotenv
from langchain.prompts.chat import (
    ChatPromptTemplate,
    SystemMessagePromptTemplate,
    HumanMessagePromptTemplate,
)



# Load environment variables (optional)
load_dotenv(find_dotenv())

# RunPod API Configuration
RUNPOD_ENDPOINT_ID = os.environ["RUNPOD_ENDPOINT_ID"]
RUNPOD_ACCESS_TOKEN = "rpa_7R9GRZPL1KSKOWTS1LVBXI2VEKTR880AA2MVC93P179q63"
CUSTOM_MODEL_NAME = "deepseek-ai/DeepSeek-R1-Distill-Qwen-7B"  # Replace with your fine-tuned DeepSeek-R1 model name
RUNPOD_ACCESS_TOKEN = "rpa_7R9GRZPL1KSKOWTS1LVBXI2VEKTR880AA2MVC93P179q63"  # Replace with your RunPod API Access Token
OPENAI_API_KEY= "rpa_7R9GRZPL1KSKOWTS1LVBXI2VEKTR880AA2MVC93P179q63" 

RUNPOD_API_URL = f"https://api.runpod.ai/v2/{RUNPOD_ENDPOINT_ID}/run"


def check_status(job_id):
    headers = {
        'Authorization': f'Bearer {RUNPOD_ACCESS_TOKEN}'
    }
    #response = requests.get(f'https://api.runpod.ai/v2/{RUNPOD_ENDPOINT_ID}/status/{job_id}', headers=headers)
    response = requests.get(f"https://api.runpod.ai/v2/94js71uw1j9ihj/status/{job_id}", headers=headers)
    

    print("resp = ", response.json())
    return response

def inference():
    headers = {
    "Authorization": f"Bearer {RUNPOD_ACCESS_TOKEN}",
    "Content-Type": "application/json"
    }

    
    text = "Explain quantum computing in simple terms."

    data = {
        'input': {
            "prompt": "Explain quantum computing in simple terms.",
            'sampling_params': {
                "max_tokens": 2048,
                'temperature': 0
            }
        }
    }
    
    response = requests.post("https://api.runpod.ai/v2/94js71uw1j9ihj/run", headers=headers, json=data)
    print("RAW TEXT:", response.text)  # Print the raw string

    #print("response = ", response)

    """
    try:
        response_json = response.json()  # Try to parse JSON
        print("Raw JSON Response:", json.dumps(response_json, indent=4))
    except json.JSONDecodeError as e:
        print("JSON Decode Error:", e)
        print("Raw Response Text:", response.text)  # Print raw response
        return None
    """
    #job_id = response.json()['id']
    print("2")
    job_id = response.json()["id"]
    print("3")
    print("job_id = ",job_id)

    counter = 0
    while True:
        counter = counter + 1
        print("Counter = ", counter)
        status = check_status(job_id)
        print("status = ", status.json()['status'])
        if status.json()['status'] == "COMPLETED":
            break

        time.sleep(0.1)
    #print("status =  ", status.json())
    #reply = status.json()['output'][0]['choices'][0]['tokens'][0]#
    #print("reply =  ", reply)

    if '</think' in reply:
        reply = reply.split('</think>')[1].strip()
    return reply

#text = {'body':'Explain quantum computing in simple terms.'}
response = inference()

print("Raw Response:", response)  # Debugging step

#print(response_text)
# Out:
# RAW TEXT: {"id":"bc768be8-b276-48a1-b841-26632eb6273b-u1","status":"IN_QUEUE"}
# 2
# 3
# job_id =  bc768be8-b276-48a1-b841-26632eb6273b-u1
# Counter =  1
# resp =  {'id': 'bc768be8-b276-48a1-b841-26632eb6273b-u1', 'status': 'IN_QUEUE'}
# status =  IN_QUEUE
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[46], line 96
#      93     return reply
#      95 #text = {'body':'Explain quantum computing in simple terms.'}
# ---> 96 response = inference()
#      98 print("Raw Response:", response)  # Debugging step
#     100 #print(response_text)
#
# Cell In[46], line 86, in inference()
#      83     if status.json()['status'] == "COMPLETED":
#      84         break
# ---> 86     time.sleep(0.1)
#      87 #print("status =  ", status.json())
#      88 #reply = status.json()['output'][0]['choices'][0]['tokens'][0]#
#      89 #print("reply =  ", reply)
#      91 if '</think' in reply:
#
# NameError: name 'time' is not defined

# %%
import os
import requests
import time
from langchain_community.chat_models import ChatOpenAI
from langchain.chains import LLMChain
from dotenv import find_dotenv, load_dotenv
from langchain.prompts.chat import (
    ChatPromptTemplate,
    SystemMessagePromptTemplate,
    HumanMessagePromptTemplate,
)



# Load environment variables (optional)
load_dotenv(find_dotenv())

# RunPod API Configuration
#RUNPOD_ENDPOINT_ID = os.environ["RUNPOD_ENDPOINT_ID"]
RUNPOD_ENDPOINT_ID = "94js71uw1j9ihj"
CUSTOM_MODEL_NAME = "deepseek-ai/DeepSeek-R1-Distill-Qwen-7B"  # Replace with your fine-tuned DeepSeek-R1 model name
RUNPOD_ACCESS_TOKEN = "rpa_7R9GRZPL1KSKOWTS1LVBXI2VEKTR880AA2MVC93P179q63"  # Replace with your RunPod API Access Token
#OPENAI_API_KEY= "rpa_7R9GRZPL1KSKOWTS1LVBXI2VEKTR880AA2MVC93P179q63" 
print(RUNPOD_ENDPOINT_ID)

RUNPOD_API_URL = f"https://api.runpod.ai/v2/{RUNPOD_ENDPOINT_ID}/run"


def check_status(job_id):
    headers = {
        'Authorization': f'Bearer {RUNPOD_ACCESS_TOKEN}'
    }
    response = requests.get(f'https://api.runpod.ai/v2/{RUNPOD_ENDPOINT_ID}/status/{job_id}', headers=headers)
    #response = requests.get(f"https://api.runpod.ai/v2/94js71uw1j9ihj/status/{job_id}", headers=headers)
    

    print("resp = ", response.json())
    return response

def inference():
    headers = {
    "Authorization": f"Bearer {RUNPOD_ACCESS_TOKEN}",
    "Content-Type": "application/json"
    }

    
    text = "Explain quantum computing in simple terms."

    data = {
        'input': {
            "prompt": "Explain quantum computing in simple terms.",
            'sampling_params': {
                "max_tokens": 2048,
                'temperature': 0
            }
        }
    }
    
    response = requests.post("https://api.runpod.ai/v2/94js71uw1j9ihj/run", headers=headers, json=data)
    print("RAW TEXT:", response.text)  # Print the raw string

    #print("response = ", response)

    """
    try:
        response_json = response.json()  # Try to parse JSON
        print("Raw JSON Response:", json.dumps(response_json, indent=4))
    except json.JSONDecodeError as e:
        print("JSON Decode Error:", e)
        print("Raw Response Text:", response.text)  # Print raw response
        return None
    """
    job_id = response.json()["id"]
    print("job_id = ",job_id)
    
    

    try:
        while True:
            status = check_status(job_id)
            status_json = status.json()
            if status_json.get('status') == "COMPLETED":
                break
            time.sleep(4)
    except Exception as e:
        print(f"❌ Error fetching job status: {e}")
    
    reply = status.json().get('output')[0].get('choices')[0].get('tokens')[0]
    if '</think' in reply:
        reply = reply.split('</think>')[1].strip()
        print("reply =  ", reply)
    return reply
    

    

#text = {'body':'Explain quantum computing in simple terms.'}
response=inference()

print("Raw Response:", response)  # Debugging step

#print(response_text)
# Out:
# 94js71uw1j9ihj
# RAW TEXT: {"id":"bcae2256-160b-48e4-96b2-e57f56e13fe5-u2","status":"IN_QUEUE"}
# job_id =  bcae2256-160b-48e4-96b2-e57f56e13fe5-u2
# resp =  {'delayTime': 17, 'id': 'bcae2256-160b-48e4-96b2-e57f56e13fe5-u2', 'status': 'IN_PROGRESS', 'workerId': 'f4l2xmx1uoj8mt'}
# resp =  {'delayTime': 17, 'id': 'bcae2256-160b-48e4-96b2-e57f56e13fe5-u2', 'status': 'IN_PROGRESS', 'workerId': 'f4l2xmx1uoj8mt'}
# resp =  {'delayTime': 17, 'id': 'bcae2256-160b-48e4-96b2-e57f56e13fe5-u2', 'status': 'IN_PROGRESS', 'workerId': 'f4l2xmx1uoj8mt'}
# resp =  {'delayTime': 17, 'id': 'bcae2256-160b-48e4-96b2-e57f56e13fe5-u2', 'status': 'IN_PROGRESS', 'workerId': 'f4l2xmx1uoj8mt'}
# resp =  {'delayTime': 17, 'id': 'bcae2256-160b-48e4-96b2-e57f56e13fe5-u2', 'status': 'IN_PROGRESS', 'workerId': 'f4l2xmx1uoj8mt'}
# resp =  {'delayTime': 17, 'executionTime': 20348, 'id': 'bcae2256-160b-48e4-96b2-e57f56e13fe5-u2', 'output': [{'choices': [{'tokens': ["\nQuantum computing is a type of computing that uses quantum-mechanical phenomena, such as superposition and entanglement, to perform operations on data. Unlike classical computers, which use bits to represent information as either 0 or 1, quantum computers use quantum bits, or qubits, which can exist in multiple states simultaneously. This allows quantum computers to process a vast amount of information at once, potentially solving certain problems much faster than classical computers can.\n\nIn simple terms, quantum computing is a new way of processing information that takes advantage of the strange and unique properties of tiny particles like atoms and subatomic particles. These properties allow quantum computers to perform certain calculations much more efficiently than traditional computers. For example, quantum computers can factor large numbers or simulate quantum systems much faster than classical computers can. This could have significant implications for fields like cryptography, drug discovery, and optimization problems.\n\nOne of the key differences between quantum computing and classical computing is the concept of superposition. In classical computing, a bit is either 0 or 1, but in quantum computing, a qubit can be in a superposition of states, meaning it can be both 0 and 1 at the same time. This allows quantum computers to perform many calculations simultaneously, which can lead to exponential speedups for certain types of problems.\n\nAnother important concept in quantum computing is entanglement. Entangled qubits are linked in such a way that the state of one qubit directly influences the state of another, no matter the distance between them. This can be used to create correlations between qubits that can be harnessed for specific computations.\n\nQuantum computing also relies on quantum interference, which is the manipulation of the probabilities of different computational paths to achieve the desired result. By carefully controlling the interference of these paths, quantum algorithms can amplify the correct answers and cancel out the incorrect ones.\n\nDespite these advantages, quantum computing is still in its early stages of development. Building and maintaining quantum computers is incredibly challenging due to issues like quantum decoherence, where the quantum state of qubits is easily disrupted by environmental noise. Additionally, quantum algorithms are still being developed, and it's not yet clear which problems will benefit the most from quantum computing.\n\nIn summary, quantum computing is a promising new paradigm for computing that leverages the principles of quantum mechanics to perform certain calculations much more efficiently than classical computers. While there are still many challenges to overcome, the potential applications of quantum computing are vast and could revolutionize many areas of science, technology, and society.\n</think>\n\nQuantum computing is a revolutionary approach to processing information that harnesses the unique properties of quantum mechanics, such as superposition and entanglement. Unlike classical computers that use bits (0 or 1), quantum computers use qubits, which can exist in multiple states simultaneously. This allows quantum computers to perform many calculations at once, potentially solving certain problems exponentially faster. While still in development, quantum computing holds significant potential for breakthroughs in fields like cryptography, drug discovery, and optimization."]}], 'usage': {'input': 9, 'output': 608}}], 'status': 'COMPLETED', 'workerId': 'f4l2xmx1uoj8mt'}
# reply =   Quantum computing is a revolutionary approach to processing information that harnesses the unique properties of quantum mechanics, such as superposition and entanglement. Unlike classical computers that use bits (0 or 1), quantum computers use qubits, which can exist in multiple states simultaneously. This allows quantum computers to perform many calculations at once, potentially solving certain problems exponentially faster. While still in development, quantum computing holds significant potential for breakthroughs in fields like cryptography, drug discovery, and optimization.
# Raw Response: Quantum computing is a revolutionary approach to processing information that harnesses the unique properties of quantum mechanics, such as superposition and entanglement. Unlike classical computers that use bits (0 or 1), quantum computers use qubits, which can exist in multiple states simultaneously. This allows quantum computers to perform many calculations at once, potentially solving certain problems exponentially faster. While still in development, quantum computing holds significant potential for breakthroughs in fields like cryptography, drug discovery, and optimization.

# %%
import os
import requests
import time
from langchain.chains import LLMChain
from langchain_core.language_models import LLM
from langchain_core.outputs import Generation
from typing import List
from dotenv import find_dotenv, load_dotenv
from langchain.prompts.chat import (
    ChatPromptTemplate,
    SystemMessagePromptTemplate,
    HumanMessagePromptTemplate,
)

# Load environment variables (optional)
load_dotenv(find_dotenv())

# RunPod API Configuration

# RunPod API Configuration
#RUNPOD_ENDPOINT_ID = os.environ["RUNPOD_ENDPOINT_ID"]
RUNPOD_ENDPOINT_ID = "94js71uw1j9ihj" 
#RUNPOD_ACCESS_TOKEN = os.environ["RUNPOD_ACCESS_TOKEN"]
CUSTOM_MODEL_NAME = "deepseek-ai/DeepSeek-R1-Distill-Qwen-7B"  # Replace with your fine-tuned DeepSeek-R1 model name
RUNPOD_ACCESS_TOKEN = "rpa_7R9GRZPL1KSKOWTS1LVBXI2VEKTR880AA2MVC93P179q63"  # Replace with your RunPod API Access Token
#OPENAI_API_KEY= "rpa_7R9GRZPL1KSKOWTS1LVBXI2VEKTR880AA2MVC93P179q63" 

RUNPOD_API_URL = f"https://api.runpod.ai/v2/{RUNPOD_ENDPOINT_ID}/run"


def check_status(job_id):
    headers = {
        'Authorization': f'Bearer {RUNPOD_ACCESS_TOKEN}'
    }
    response = requests.get(f'https://api.runpod.ai/v2/{RUNPOD_ENDPOINT_ID}/status/{job_id}', headers=headers)
    #response = requests.get(f"https://api.runpod.ai/v2/94js71uw1j9ihj/status/{job_id}", headers=headers)
    return response


class CustomDeepSeekR1(LLM):
    """ Custom LangChain wrapper for fine-tuned DeepSeek-R1 model on RunPod """
    def _call(self, prompt: str, stop=None) -> str:
        #super()._call(**kwargs)
        HEADERS = {
            "Authorization": f"Bearer {RUNPOD_ACCESS_TOKEN}",
            "Content-Type": "application/json"
        }

        payload = {
            "input": {
                "model": CUSTOM_MODEL_NAME,
                "prompt": prompt,
                "sampling_params": {
                    "max_tokens": 2048,
                    "temperature": 0
                }
            }
        }
        #print("prompt = ", prompt)

        response = requests.post(RUNPOD_API_URL, json=payload, headers=HEADERS)
        job_id = response.json()["id"]

        try:
            while True:
                status = check_status(job_id)
                status_json = status.json()
                #print("stats_json", status_json)
                if status_json.get('status') == "COMPLETED":
                    response_data = status.json().get('output')[0].get('choices')[0].get('tokens')[0]
                    break
                time.sleep(4)
        except Exception as e:
            print(f"❌ Error fetching job status: {e}")   
        #print("response_data = ", response_data) 
        if '</think' in response_data:
            response_data = response_data.split('</think>')[1].strip()
        return response_data
    
    @property
    def _llm_type(self) -> str:
        return "custom-runpod-deepseek"



# Function to draft an email using DeepSeek-R1 fine-tuned model
def draft_email(user_input, name="There"):

    template = """
    You are a helpful assistant that drafts an email reply based on an a new email.
    Your goal is to help the user quickly create a perfect email reply.
    Keep your reply short and to the point and mimic the style of the email so you reply in a similar manner to match the tone.
    Start your reply by saying: "Hi {name}, here's a draft for your reply:". And then proceed with the reply on a new line.
    Make sure to sign off with {signature}.
    """

    signature = f"Kind regards, \n"
    system_message_prompt = SystemMessagePromptTemplate.from_template(template)

    human_template = "Here's the email to reply to and consider any other comments from the user for reply as well: {user_input}"
    human_message_prompt = HumanMessagePromptTemplate.from_template(human_template)

    chat_prompt = ChatPromptTemplate.from_messages(
        [system_message_prompt, human_message_prompt]
    )

    chat = CustomDeepSeekR1(model_name=CUSTOM_MODEL_NAME)
    chain = LLMChain(llm=chat, prompt=chat_prompt)
    response = chain.run(user_input=user_input, signature=signature, name=name)
    if '</think' in response:
        response = response.split('</think>')[1].strip()

    print("final response = ", response)
    return response


inp = "Tell me something about Quantum computing applications in modern world, in less than 50 words"
email_response = draft_email(user_input="Tell me something about Quantum computing applications in modern world, in less than 50 words", name="There")
# Out:
# final response =  Hi There, here's a draft for your reply:
# Quantum computing has the potential to revolutionize fields like cryptography, optimization, and drug discovery by solving complex problems much faster than classical computers. It's already making significant impacts in areas such as machine learning and materials science. Kind regards,
